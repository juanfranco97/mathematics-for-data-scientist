# %% [markdown]
# ## Matrix Descomposition

# %%
# %matplotlib  inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "funciones_auxiliares\graficarVectores.ipynb"

# %%
orange_light = '#FF9A13'
blue_light = '#1190FF'

# %% [markdown]
# Descomponer una matriz: Quiere decir encontrar dos o más matrices que me ayuden a escribir la matriz original y que tengan ciertas propiedades.
# Una matriz A la podemos escribir como: sus autovectores producto punto una matriz diagonal, donde la matriz diagonal tiene todos los autovalores encontrados, producto punto la matriz inversa de sus autovectores.
# A_calc = autovectores.dot(np.diag(autovalores)).dot(np.linalg.inv(autovectores))
# Descomposición 2: Restricciones:Nuestra Matriz A sea real y simétrica (A = A-transpuesta). Decimos que A = la matriz de autovectores producto punto la matriz diagonal con los autovalores, producto punto la transpuesta de la matriz de autovectores. NOTA: Calcular la transpuesta de una matriz es mucho más económico en cómputo que calcular la inversa de una matriz. Y hay que recordar que el cómputo cuesta dinero.
# A_calc = autovectores.dot(np.diag(autovalores)).dot(autovectores.T)

# %%
A= np.array([[3,2],[4,1]])
A
# Out:
# array([[3, 2],
#        [4, 1]])

# %%
autovalores, autovectores = np.linalg.eig(A)

# %%
print(autovalores)
print(autovectores)
# Out:
# [ 5. -1.]
# [[ 0.70710678 -0.4472136 ]
#  [ 0.70710678  0.89442719]]

# %%
A_calc = autovectores.dot(np.diag(autovalores)).dot(np.linalg.inv(autovectores))
A_calc
# Out:
# array([[3., 2.],
#        [4., 1.]])

# %%
A_calc == A

# %%
# si A es real y simetrica(A=AT)
A= np.array([[3,2],[2,3]])
A
# Out:
# array([[3, 2],
#        [2, 3]])

# %%
print(A == A.T)
# Out:
# [[ True  True]
#  [ True  True]]

# %%
autovalores, autovectores = np.linalg.eig(A)
print(autovalores)
print(autovectores)
# Out:
# [5. 1.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
A_calc = autovectores.dot(np.diag(autovalores)).dot(autovectores.T)
A_calc
# CALCULAR UNA TRASPUESTA ES MAS FACIL QUE CALCULAR UNA INVERSA
# Out:
# array([[3., 2.],
#        [2., 3.]])

# %% [markdown]
# ## descomposicion en valores singulares para matrices no cuadradas

# %%
A = np.array([[1,2,3],[3,4,5]])
A
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
U, D, V =np.linalg.svd(A)

# %%
U
# Out:
# array([[-0.46410668, -0.88577931],
#        [-0.88577931,  0.46410668]])

# %%
D
# Out:
# array([7.97638869, 0.61418515])

# %%
V
# Out:
# array([[-0.39133557, -0.5605708 , -0.72980603],
#        [ 0.8247362 ,  0.13817999, -0.54837623],
#        [ 0.40824829, -0.81649658,  0.40824829]])

# %%
print(np.diag(D))
# Out:
# [[7.97638869 0.        ]
#  [0.         0.61418515]]

# %%
# %run "funciones_auxiliares\graficarMatriz.ipynb"

# %%
A = np.array([[3,7],[5,2]])
A
# Out:
# array([[3, 7],
#        [5, 2]])

# %%
print('Circulo unitario:')
graficarMatriz(np.array([[1,0],[0,1]]))

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()

print('Circulo unitario:')
graficarMatriz(A)

plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
# Out:
# Circulo unitario:
# Circulo unitario:

# %%
U,D,V = np.linalg.svd(A)

# %%
print('Circulo unitario:')
graficarMatriz(np.array([[1,0],[0,1]]))

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()

print('Primer rotacion V:')
graficarMatriz(V)

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()

print('Escala(D):')
graficarMatriz(np.diag(D).dot(V))

plt.xlim(-9,9)
plt.ylim(-9,9)
plt.show()

print('Segunda rotacion U:')
graficarMatriz(U.dot(np.diag(D).dot(V)))

plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
# Out:
# Circulo unitario:
# Primer rotacion V:
# Escala(D):
# Segunda rotacion U:

# %% [markdown]
# La matriz V rota el espacio
# La matriz D escala el espacio.
# La matriz U rota de nuevo el espacio.
# La transformación del espacio de una matriz A es igual a la transformación de las matrices SVD (Valores singulares)

# %% [markdown]
# ## interpretacion de los valores singulares

# %%
A= np.array([[3,7],[5,2]])
A
# Out:
# array([[3, 7],
#        [5, 2]])

# %%
U, D, V = np. linalg.svd(A)

# %%
print(D[0])
print(D[1])
# Out:
# 8.7133796929634
# 3.3282148858288965

# %%
u1 = [D[0]*U[0,0], D[0]*U[0,1]]
v1 = [D[1]*U[1,0], D[1]*U[1,1]]

print([A[0,0],A[1,0]])
print(u1)
print()
print([A[0,1],A[1,1]])
print(v1)
# Out:
# [3, 5]
# [-7.4120434792975685, -4.580894796297923]
#
# [7, 2]
# [-1.7497461132982814, 2.8311486829996433]

# %%
graficarMatriz(A)
graficarVectores([u1,v1], cols=['red','blue'])

plt.text(3,5,r"$u_1$", size =18)
plt.text(7,2,r"$v_1$", size =18)
plt.text(-5,-4,r"$D(u_1)$", size =18)
plt.text(-4,1,r"$D(v_1)$", size =18)

plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ## aplicando SVD  a una imagen

# %%
from PIL import Image

# %%
plt.style.use('classic')
imagen = Image.open('imagenes\imagen_ejemplo_frida_bredesen.jpg')

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=3693x3456 at 0x121F44D7B08>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
imagen_mat
# Out:
# array([236., 236., 235., ..., 195., 195., 193.])

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 239. 239. 239.]
#  [236. 236. 235. ... 238. 238. 238.]
#  ...
#  [217. 216. 216. ... 197. 196. 194.]
#  [216. 216. 216. ... 196. 195. 193.]
#  [216. 216. 216. ... 195. 195. 193.]]

# %%
print(imagen_mat.shape)
# Out:
# (3456, 3693)

# %%
plt.imshow(imagen_mat, cmap = 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
imagen_mat_2 = imagen_mat /10
imagen_mat_2
# Out:
# array([[23.6, 23.6, 23.5, ..., 23.9, 23.9, 23.9],
#        [23.6, 23.6, 23.5, ..., 23.9, 23.9, 23.9],
#        [23.6, 23.6, 23.5, ..., 23.8, 23.8, 23.8],
#        ...,
#        [21.7, 21.6, 21.6, ..., 19.7, 19.6, 19.4],
#        [21.6, 21.6, 21.6, ..., 19.6, 19.5, 19.3],
#        [21.6, 21.6, 21.6, ..., 19.5, 19.5, 19.3]])

# %%
plt.imshow(imagen_mat_2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(imagen_mat_2, cmap = 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Al dividir los valores de la imagen, se ve un cambio en la escala de los colores, pero si se hace leyendo en escala de grises, se obtiene la imagen original en escala de grises, eso quiere decir que lee la relación entre los pixeles, no es literal en la lectura de cada pixel.

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 24.4
# 244.0

# %%
print(np.min(imagen_mat_2))
print(np.min(imagen_mat))
# Out:
# 2.5
# 25.0

# %%
U,D,V = np.linalg.svd(imagen_mat)

# %%
print(imagen_mat.shape)
print(U.shape)
print(D.shape)
print(V.shape)
# Out:
# (3456, 3693)
# (3456, 3456)
# (3456,)
# (3693, 3693)

# %%
imagen_recons= np.matrix(U[:, :1])*np.diag(D[:1])*np.matrix(V[:1,:])
plt.imshow(imagen_recons, cmap='gray')

# %%
i=5
imagen_recons= np.matrix(U[:, :i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons, cmap='gray')

title="valores singulares = %s" %i

plt.title(title)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
i=10
imagen_recons= np.matrix(U[:, :i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons, cmap='gray')

title="valores singulares = %s" %i

plt.title(title)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
i=25
imagen_recons= np.matrix(U[:, :i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons, cmap='gray')

title="valores singulares = %s" %i

plt.title(title)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
i=50
imagen_recons= np.matrix(U[:, :i])*np.diag(D[:i])*np.matrix(V[:i,:])
plt.imshow(imagen_recons, cmap='gray')

title="valores singulares = %s" %i

plt.title(title)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# la compresión de imágenes por SVD hace uso de que muy pocos de los valores singulares realmente representan información.
# Los valores singulares se guardan de forma ordenada.

# %% [markdown]
# ## pseudoinversa

# %% [markdown]
# La pseudo inversa de Moore Penrose es una aplicación directa de SVD, que nos permite resolver en determinados momentos sistemas de ecuaciones lineales con múltiples soluciones.
#
# La forma en que python obtiene la pseudo inversa es con el método SVD.
# SVD es mas certera, y computacionalmente más efectiva.

# %%
np.set_printoptions(suppress=True)
# valores cercanos a 0 mostrados como 0

# %%
A = np.array([[2,3],[5,7],[11,13]])
A
# Out:
# array([[ 2,  3],
#        [ 5,  7],
#        [11, 13]])

# %%
U,D,V = np.linalg.svd(A)

# %%
print("U")
print(U)
print("D")
print(D)
print("V")
print(V)
# Out:
# U
# [[-0.18499741 -0.47276624 -0.86154979]
#  [-0.44249308 -0.74271297  0.50257071]
#  [-0.87748267  0.4742041  -0.07179582]]
# D
# [19.40321383  0.71783924]
# V
# [[-0.63055377 -0.77614557]
#  [ 0.77614557 -0.63055377]]

# %%
D_pse = np.zeros((A.shape[0], A.shape[1])).T
D_pse
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
print("Valores a remplazar en D_pse")
print(D_pse[:D.shape[0], :D.shape[0]])
# Out:
# Valores a remplazar en D_pse
# [[0. 0.]
#  [0. 0.]]

# %%
print("Valores que pndremos en D_pse")
print(np.linalg.inv(np.diag(D)))
# Out:
# Valores que pndremos en D_pse
# [[0.05153785 0.        ]
#  [0.         1.39306957]]

# %%
print(" D_pse")
D_pse[:D.shape[0], :D.shape[0]]=np.linalg.inv(np.diag(D))
print(D_pse)
# Out:
#  D_pse
# [[0.05153785 0.         0.        ]
#  [0.         1.39306957 0.        ]]

# %%
#A_pse =V D_pse UT
A_pse = V.T.dot(D_pse).dot(U.T)
A_pse
# Out:
# array([[-0.50515464, -0.78865979,  0.54123711],
#        [ 0.42268041,  0.67010309, -0.3814433 ]])

# %%
# calculandolo por numpy
A_pse_calc = np.linalg.pinv(A)
A_pse_calc
# Out:
# array([[-0.50515464, -0.78865979,  0.54123711],
#        [ 0.42268041,  0.67010309, -0.3814433 ]])

# %%
# comprovacion
print(A_pse.dot(A))
# casi es la identidad
# Out:
# [[ 1. -0.]
#  [ 0.  1.]]

# %%
np.set_printoptions(suppress=False)
print(A_pse.dot(A))
# Out:
# [[ 1.00000000e+00 -2.66453526e-15]
#  [ 2.66453526e-15  1.00000000e+00]]

# %% [markdown]
# Esta pseudo inversa no tiene las mismas propiedades que una inversa pero es muy util

# %%
# otra forma de calcular la pseudo inversa por otro metodo
A_pse_2 = np.linalg.inv(A.T.dot(A)).dot(A.T)
A_pse_2
# Out:
# array([[-0.50515464, -0.78865979,  0.54123711],
#        [ 0.42268041,  0.67010309, -0.3814433 ]])

# %% [markdown]
# python utiliza el metodo SVD A_pse

# %% [markdown]
# ## Usando la pseudo inversa para resolver un sistema sobredeterminando

# %%
x= np.linspace(-5,5,1000)

y_1 = 1*x+4 #-4*x+3
y_2 = 2*x+5
y_3 = -3*x+6 #-3*x+1

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.show()

# %%
matriz = np.array([[-1,1],[-2,1],[3,1]]) 
#matriz = np.array([[4,1],[-2,1],[3,1]]) 
matriz
# Out:
# array([[-1,  1],
#        [-2,  1],
#        [ 3,  1]])

# %%
matriz_pse = np.linalg.pinv(matriz)
matriz_pse
# Out:
# array([[-0.07142857, -0.14285714,  0.21428571],
#        [ 0.33333333,  0.33333333,  0.33333333]])

# %%
b= np.array([[4],[5],[6]])
#b= np.array([[3],[5],[1]])
b
# Out:
# array([[4],
#        [5],
#        [6]])

# %%
resultado = matriz_pse.dot(b)
resultado
# Out:
# array([[0.28571429],
#        [5.        ]])

# %%
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-2,2.5)
plt.ylim(-6,6)
plt.scatter(resultado[0],resultado[1])
plt.show()

# %% [markdown]
# como las ecuaciones no se tocan naturalmente en ningun punto, no hay una solucion exacta al sistema de ecuaciones pero con la matriz de pseudo inversa podemos encontrar un punto de aproximacion.

# %% [markdown]
# ## ¿Qué es PCA?
#
# La maldición de la dimensión: Esto dice que por cada variable que agrego en el conjunto de datos vamos a necesitar exponencialmente más muestras para poder tener la misma relevancia estadística.
# Cuál es el autovector relacionado con el autovalor más grande? Es el autovalor quien define cual es la dirección que contiene más información.

# %%
np.random.seed(42)
x= 3*np.random.rand(200)
y= 20*x+2*np.random.randn(200)

x = x.reshape(200,1)
y= y.reshape(200,1)

# %%
xy = np.hstack([x,y])
print(xy.shape)
# Out:
# (200, 2)

# %%
plt.plot(xy[:,0],xy[:,1],'.')
plt.show()

# %%
xy_centrado = xy - np.mean(xy, axis=0)

# %%
plt.plot(xy_centrado[:,0], xy_centrado[:,1],'.')
plt.show()

# %%
autovalores, autovectores = np.linalg.eig(xy_centrado.T.dot(xy_centrado))

# %%
graficarVectores(autovectores.T, ['blue', 'red'])

plt.plot(xy_centrado[:,0], xy_centrado[:,1]/20, '.')
plt.show()

# %%
autovalores
# Out:
# array([1.85050946e+00, 6.28759594e+04])

# %%
xy_nuevo = autovectores.T.dot(xy_centrado.T)

# %%
plt.plot(xy_nuevo[0,:], xy_nuevo[1,:], '.')
plt.show()

# %% [markdown]
# ## Apliquemos PCA a un conjunto de imágenes

# %% [markdown]
# PCA es una técnica muy útil para reducir la cantidad de dimensiones con las que estamos trabajando.
# Muchas veces nuestro conjunto de datos es muy grande y es necesario reducirlo al menos en un 20%, dejando el 80% de datos mas significativo.

# %%
import pandas as pd

# %%
import imageio

# %%
import sklearn.datasets
data= sklearn.datasets.fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\ASUS\scikit_learn_data

# %%
im = imageio.imread('')
im = im.astype(np.uint8)
print(im)

# %%
print('Max original', end=' ')
print(np.amax(im))
print('Min original', end=' ')
print(np.amin(im))

# %%
im_original = im
im= im/255
print('Max original', end=' ')
print(np.amax(im))
print('Min original', end=' ')
print(np.amin(im))

# %%
fix, ax = plt.subplots(1,2, figsize=(12,12),
                      subplot_kw = {'xticks': [], 'yticks':[]})
ax[0].imshow(im_original, cmap='gray')
ax[1].imshow(im, cmap='gray')

# %%
from glob import iglob
caras= pd.DataFrame([])
for path in iglob('imagenes\*\*.png'):
    im= imageio.imread(path)
    cara = pd.Series(im.flatten(), name=path)
    caras = caras.append(cara)
    
fig, axes = plt.subplots(5,10, figsize=(15,8),
                      subplot_kw = {'xticks': [], 'yticks':[]},
                        gridspec_kw = dict(hspace= 0.01, wspace = 0.01))

for i, ax in enumerate(axes.flat):
    ax.imshow(caras.iloc[i].values.reshape(112,92), smap="gray")

# %%
from sklearn.decomposition import PCA

# %%
caras_pca = PCA(n_components=0.5)
caras_pca.fit(caras)

# %%
filas = 3
columns = caras_pca.n_components_ // filas

fig, axes = plt.subplots(filas,columns, figsize=(12,6),
                      subplot_kw = {'xticks': [], 'yticks':[]},
                        gridspec_kw = dict(hspace= 0.01, wspace = 0.01))

for i, ax in enumerate(axes.flat):
    ax.imshow(caras_pca.componentes_[i].reshape(112,92), smap="gray")

# %%
print(caras_pca.n_componentes_)

# %%
componentes = caras_pca.transform(caras)
proyeccion= caras_pca.inverse_transform(componentes)

fig, axes = plt.subplots(5,10, figsize=(15,8),
                      subplot_kw = {'xticks': [], 'yticks':[]},
                        gridspec_kw = dict(hspace= 0.01, wspace = 0.01))

for i, ax in enumerate(axes.flat):
    ax.imshow(proyeccion[i].reshape(112,92), smap="gray")

# %%
A= np.array([[1,2],[3,4],[5,6]])
A_pse_calc = np.linalg.pinv(A)
A_pse_calc
# Out:
# array([[-1.33333333, -0.33333333,  0.66666667],
#        [ 1.08333333,  0.33333333, -0.41666667]])

# %% [markdown]
# referencias :
#
# -https://github.com/rb-one/-Curso_Algebra_Lineal_Aplicada_para_ML/blob/master/Notes/note.md
#
# -https://github.com/ivanachillee/pcalib
#
# -https://medium.com/@sebastiannorena/pca-principal-components-analysis-applied-to-images-of-faces-d2fc2c083371
